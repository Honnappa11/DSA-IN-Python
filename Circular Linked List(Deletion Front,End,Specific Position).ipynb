# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class CLL:
    def __init__(self):
        self.head=None
        self.tail=None
    def display(self):
        if self.head is None:
            print("linked list is empty")
        else:
            temp=self.head
            print(temp.data,'-->',end=" ")
            while temp.next != self.head:
                temp=temp.next
                print(temp.data,'-->',end=" ")
            print(temp.next.data)
    def delete_front(self):
        if self.head is None:
            print("Empty List")
        else:
            if self.head == self.tail:
                self.head=None
            else:
                temp=self.head
                self.head=temp.next
                self.tail.next=self.head
                temp.next=None
    def delete_end(self):
        if self.head is None:
            print("Empty List")
        else:
            if self.head == self.tail:
                self.head=None
            else:
                temp=self.head
                while temp.next !=self.tail:
                    temp=temp.next
                temp.next=self.head
                self.tail.next=None
                self.tail=temp
    def delete_position(self,pos):
        if self.head is None:
            print("linked list is empty")
        elif pos==1:
            delete_front()
        else:
            temp1=self.head
            temp2=self.head.next
            for i in range(1,pos-1):
                temp1=temp1.next
                temp2=temp2.next
            temp1.next=temp2.next
            if temp2 ==self.tail:
                self.tail=temp1
            temp2=None
c=CLL()
n1=Node(10)
c.head=n1
c.tail=n1
c.tail.next=c.head

n2=Node(20)
c.tail.next=n2
c.tail=n2
c.tail.next=c.head

n3=Node(30)
c.tail.next=n3
c.tail=n3
c.tail.next=c.head

n4=Node(40)
c.tail.next=n4
c.tail=n4
c.tail.next=c.head
#c.delete_front()
#c.delete_front()
#c.delete_end()
#c.delete_end()
#c.delete_end()
#c.delete_end()
c.delete_position()
c.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 84
#      77 c.tail.next=c.head
#      78 #c.delete_front()
#      79 #c.delete_front()
#      80 #c.delete_end()
#      81 #c.delete_end()
#      82 #c.delete_end()
#      83 #c.delete_end()
# ---> 84 c.delete_position()
#      85 c.display()
#
# TypeError: CLL.delete_position() missing 1 required positional argument: 'pos'
